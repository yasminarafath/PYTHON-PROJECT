# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv(r'C:\Users\user\Downloads\myexcel - myexcel.csv.csv')

# Replace height with random values between 150 and 180
np.random.seed(42)
df['height'] = np.random.randint(150, 181, size=len(df))

# Check for nulls and data types
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
#  9   height    458 non-null    int32
# dtypes: float64(1), int32(1), int64(3), object(5)
# memory usage: 34.1+ KB
# None
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# height       0
# dtype: int64

# %%
team_counts = df['Team'].value_counts()
team_percentage = df['Team'].value_counts(normalize=True) * 100

# Visualization
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
team_counts.plot(kind='bar', color='skyblue')
plt.title("Employee Distribution Across Teams")
plt.ylabel("Number of Employees")
plt.xlabel("Team")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
position_counts = df['Position'].value_counts()

# Visualization
position_counts.plot(kind='barh', color='coral')
plt.title("Employee Count by Position")
plt.xlabel("Number of Employees")
plt.ylabel("Position")
plt.tight_layout()
plt.show()

# %%
# Create age bins
bins = [20, 30, 40, 50, 60]
labels = ['21-30', '31-40', '41-50', '51-60']
df['age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True)

age_group_counts = df['age_group'].value_counts().sort_index()

# Visualization
age_group_counts.plot(kind='bar', color='mediumseagreen')
plt.title("Predominant Age Group of Employees")
plt.xlabel("Age Group")
plt.ylabel("Number of Employees")
plt.tight_layout()
plt.show()

# %%
team_salary = df.groupby('Team')['Salary'].sum().sort_values(ascending=False)
position_salary = df.groupby('Position')['Salary'].sum().sort_values(ascending=False)

# Visualization
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
team_salary.plot(kind='bar', color='orchid')
plt.title("Salary by Team")
plt.ylabel("Total Salary")

plt.subplot(1, 2, 2)
position_salary.plot(kind='bar', color='goldenrod')
plt.title("Salary by Position")
plt.ylabel("Total Salary")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Calculate correlation
corr_value = df['Age'].corr(df['Salary'])

# Visualization
sns.scatterplot(data=df, x='Age', y='Salary', hue='Team')
plt.title(f"Correlation between Age and Salary: {corr_value:.2f}")
plt.tight_layout()
plt.show()

# %%
#Insights and Trends
#The highest concentration of employees is in the Development and Sales teams, each making up a significant share of the workforce.

#The most common job positions are Software Engineer, Sales Executive, and HR Associate.

#The 31-40 age group is the most dominant, suggesting mid-career professionals form the backbone of the company.

#The Development team has the highest salary expenditure, with Senior Developers and Project Managers being the top earners.

#A moderate positive correlation between age and salary indicates that employees earn more as they gain experience and seniority.
